# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Jeanne/Advancedweb_2401000493/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1=pd.read_csv("mexico-real-estate-1.csv")
df2=pd.read_csv("mexico-real-estate-2.csv")
df3=pd.read_csv("mexico-real-estate-3.csv")
df1.shape
df1.info()
df1.isnull().sum()
df1.head(5)
df1.dropna()
df1["price_usd"] = (
    df1["price_usd"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float))
df2.dropna()
df2["price_usd"]=df2["price_mxn"] / 19
df2.drop(columns=["price_mxn"], inplace=True)
df3.dropna()
df3[["lat","lon"]]=df3["lat-lon"].str.split(",",expand=True)
df3["State"]=df3["place_with_parent_names"].str.split("|",expand=True)[2]
df3.drop(columns=["place_with_parent_names", "lat-lon"], inplace=True)
df = pd.concat([df1, df2, df3])
df
print(df.shape)
df = pd.concat([df1, df2, df3], ignore_index=True)
df = df[["property_type", "state", "lat", "lon", "area_m2", "price_usd"]]
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_usd      700 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 32.9+ KB
# (2100, 7)
# property_type      0
# state            700
# lat              364
# lon              364
# area_m2            0
# price_usd          0
# dtype: int64
